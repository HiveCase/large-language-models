# %% [markdown]
# <a href="https://colab.research.google.com/github/HiveCase/large-language-models/blob/main/assignments/Week7/Week_7_GA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

V = [
    "[start]", "building", "character", "a", "is",
    "astronomy", "science", "experience", "natural", "[end]"
]

Y_hat = [
    0.05, 0.02, 0.14, 0.07, 0.09, 0.41, 0.08, 0.05, 0.08, 0.01,
    0.10, 0.04, 0.06, 0.16, 0.43, 0.01, 0.06, 0.09, 0.01, 0.04,
    0.05, 0.07, 0.28, 0.29, 0.03, 0.08, 0.04, 0.08, 0.04, 0.04,
    0.10, 0.02, 0.48, 0.02, 0.01, 0.07, 0.06, 0.14, 0.07, 0.01,
    0.08, 0.29, 0.04, 0.01, 0.04, 0.03, 0.25, 0.05, 0.15, 0.06,
    0.14, 0.22, 0.13, 0.08, 0.01, 0.03, 0.06, 0.23, 0.08, 0.03,
    0.10, 0.01, 0.01, 0.01, 0.07, 0.20, 0.00, 0.25, 0.05, 0.30
]

# Convert to numpy array and reshape
Y_hat = np.array(Y_hat).reshape(7, 10)

# Convert to DataFrame
df = pd.DataFrame(Y_hat, columns=V)

df
# Out:
#    [start]  building  character     a    is  astronomy  science  experience  \
# 0     0.05      0.02       0.14  0.07  0.09       0.41     0.08        0.05
# 1     0.10      0.04       0.06  0.16  0.43       0.01     0.06        0.09
# 2     0.05      0.07       0.28  0.29  0.03       0.08     0.04        0.08
# 3     0.10      0.02       0.48  0.02  0.01       0.07     0.06        0.14
# 4     0.08      0.29       0.04  0.01  0.04       0.03     0.25        0.05
# 5     0.14      0.22       0.13  0.08  0.01       0.03     0.06        0.23
# 6     0.10      0.01       0.01  0.01  0.07       0.20     0.00        0.25
#
#    natural  [end]
# 0     0.08   0.01
# 1     0.01   0.04
# 2     0.04   0.04
# 3     0.07   0.01
# 4     0.15   0.06
# 5     0.08   0.03
# 6     0.05   0.30

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1LyQZhh2FNkiLxNUKoiPDnbZ58ShdGeEttJst_n_J-bY/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1LyQZhh2FNkiLxNUKoiPDnbZ58ShdGeEttJst_n_J-bY/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
